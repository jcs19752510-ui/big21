# %%
# import 방식에 대하여 사용하는 방식이 달라진다.
# 속도의 차이는 없으니 사용하면 된다.
import sys
for path in sys.path:
    print(path)

# sys.path.append(r"./code_test/chap_02") # 현재 디렉토리를 모듈 검색 경로에 추가
# from mod1 import sum
# import chap05.xxxxxmod1 as xxxxxmod1
# import mod1 as m # 별칭 사용
# import mod1

# import mod1

# from modules.mod2 import PI, Math, sum  

# 변수 출력
# print(PI)

# a = Math()
# a.solv(2)

# print(sum(PI, 4.4))
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\python312.zip
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\DLLs
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib
# c:\Users\Admin\AppData\Local\Programs\Python\Python312
#
# C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages

# %%
sys.path
# Out:
# ['c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\DLLs',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\Lib',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312',
#  '',
#  'C:\\Users\\Admin\\AppData\\Roaming\\Python\\Python312\\site-packages',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages']

# %%
import sys # 1회성으로 생성됨.
sys.path.append(r"C:\big21\python_dev\mymodules") # 현재 디렉토리를 모듈 검색 경로에 추가

# sys.path

# import mymodules.mod2
# print(mymodules.mod2.sum(3,4))

# %%
# 목표 : echo 모듈안에 있는 echo_test() 실행
# 1. import 사용하는 경우
import game.sound.echo
game.sound.echo.echo_test()
# Out:
# sound 초기화
# echo

# %%
# 2. from ~ import module name
from game.sound import echo
echo.echo_test()
# Out:
# echo

# %%
# 3. from ~ import funtion(가장 많이 쓰는 방식)
# from game.sound.echo import echo_test
from game import echo_test , render_test
echo_test() 
render_test()
# Out:
# sound 초기화
# echo
# render
