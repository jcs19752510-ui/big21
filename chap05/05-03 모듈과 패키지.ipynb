# %%
# import 방식에 대하여 사용하는 방식이 달라진다.
# 속도의 차이는 없으니 사용하면 된다.

# import sys
# sys.path.append(r"./code_test/chap_02") # 현재 디렉토리를 모듈 검색 경로에 추가
# from mod1 import sum
from mod1 import safe_sum
# import chap05.xxxxxmod1 as xxxxxmod1
# import mod1 as m # 별칭 사용
# import mod1

# print(sum(1774,66))
print(safe_sum(111,222))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 7
#       3
#       4 # import sys
#       5 # sys.path.append(r"./code_test/chap_02") # 현재 디렉토리를 모듈 검색 경로에 추가
#       6 # from mod1 import sum
# ----> 7 from mod1 import safe_sum
#       8 # import chap05.xxxxxmod1 as xxxxxmod1
#       9 # import mod1 as m # 별칭 사용
#      10 # import mod1
#
# ImportError: cannot import name 'safe_sum' from 'mod1' (c:\big21\python_dev\chap05\mod1.py)
